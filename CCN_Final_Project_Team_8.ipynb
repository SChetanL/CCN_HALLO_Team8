# %% [markdown]
# <a href="https://colab.research.google.com/github/SChetanL/SChetanL/blob/main/CCN_Final_Project_Team_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/fudan-generative-vision/hallo.git
# Out:
# Cloning into 'hallo'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 401 (delta 153), reused 96 (delta 96), pack-reused 169 (from 1)
# Receiving objects: 100% (401/401), 43.03 MiB | 54.94 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/hallo /content/drive/MyDrive/

# %%
# %cd /content/drive/MyDrive/hallo
# Out:
# /content/drive/MyDrive/hallo

# %%
# !ls
# Out:
# accelerate_config.yaml	configs   hallo    README.md	     scripts
# assets			examples  LICENSE  requirements.txt  setup.py

# %%
# !pip install -r requirements.txt
# !pip install .
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.3/757.3 MB 1.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 117.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !sudo apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# %cd /content/drive/MyDrive/hallo
# Out:
# /content/drive/MyDrive/hallo

# %%
# !git lfs install
# !git clone https://huggingface.co/fudan-generative-ai/hallo pretrained_models
# Out:
# Updated git hooks.
# Git LFS initialized.
# Cloning into 'pretrained_models'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 61 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (61/61), 17.19 KiB | 28.00 KiB/s, done.
# Filtering content: 100% (12/12), 6.53 GiB | 39.25 MiB/s, done.
# fatal: cannot exec '/content/drive/MyDrive/hallo/pretrained_models/.git/hooks/post-checkout': Permission denied
# Encountered 1 file(s) that may not have been copied correctly on Windows:
# 	hallo/net.pth
#
# See: `git lfs help smudge` for more details.

# %%
# !pip install huggingface_hub==0.25.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.4/436.4 kB 1.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.26.2
#     Uninstalling huggingface-hub-0.26.2:
#       Successfully uninstalled huggingface-hub-0.26.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.39.2 which is incompatible.
# ...

# %%
# %cd /content/drive/MyDrive/hallo
# Out:
# /content/drive/MyDrive/hallo

# %%
# !python scripts/inference.py --source_image examples/reference_images/7.jpg --driving_audio examples/driving_audios/1.wav
# Out:
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.2.2+cu118 with CUDA 1108 (you have 2.2.2+cu121)
#     Python  3.10.14 (you have 3.10.12)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# 2024-12-02 20:04:27.463559: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-02 20:04:27.485176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
